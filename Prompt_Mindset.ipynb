# %% [markdown]
# <a href="https://colab.research.google.com/github/saharnazyp/Marketing-AI/blob/main/Prompt_Mindset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 00_why_this_phase_exists.md
# Why Phase 0 Exists
#
# Most prompt failures are not technical failures.
# They are thinking failures.
#
# This phase exists to:
#
# Break the myth of AI as a creative brain
#
# Replace “asking” with “briefing”
#
# Establish responsibility for output quality
#
# Skipping this phase guarantees shallow results in later phases.

# %% [markdown]
# 02_why_outputs_fail.md
# Why Most AI Outputs Fail
#
# Common causes:
#
# Vague prompts
#
# Missing goals
#
# Undefined audience
#
# No format control
#
# Bad output is not evidence of bad AI.
# It is evidence of missing structure.
#
# 03_command_vs_scenario.md
# Command vs Scenario
#
# Command (Wrong)

# %%
Write an Instagram caption for a restaurant.

# %% [markdown]
# Scenario (Correct)

# %%
You are a brand copywriter for a casual dining restaurant.
Target audience: 20–30 year olds.
Tone: friendly, energetic, not salesy.
Goal: increase engagement.
Output: max 2 lines.

# %% [markdown]
# 04_ai_and_creativity.md
# Creativity Is Not Outsourced
#
# AI does not create ideas.
# It expands existing ones.
#
# Bad idea × AI = polished nonsense
# Good idea × AI = scalable creativity
#
# AI amplifies direction, not imagination.
#
# 05_prompting_as_thinking.md
# Prompting Is Thinking Out Loud
#
# A good prompt is evidence of:
#
# clear intent
#
# audience awareness
#
# brand discipline
#
# Prompting is a thinking skill disguised as a writing skill.

# %% [markdown]
# Treat each episode like a campaign
#
# Ask:
#
# What was the goal of the campaign?
#
# Where was the KPI?
#
# If we had AI, where would it help?
#
# Where would it be a disaster in the real world?
#
# Professional summary
#
# Emily in Paris is like fast food:
#
# Tasty
#
# Visually inspiring
#
# But if that’s all the team’s mental diet is, they’ll be malnourished
#
# Next to it should be:
#
# Mad Men → Depth
#
# Moneyball → Data
#
# Social dilemma ← Ethics
#
# Emily in Paris → Today’s culture
#
# With this combination, the team both understands the trend and doesn’t get fooled by it.

# %% [markdown]
# هر اپیزود را مثل یک کمپین ببینند
#
# بپرسند:
#
# هدف کمپین چی بود؟
#
# KPI کجا بود؟
#
# اگر AI داشتیم، کجا کمک می‌کرد؟
#
# کجاش در دنیای واقعی فاجعه می‌شد؟
#
# جمع بندی حرفه ای
#
# امیلی در پاریس مثل فست‌فوده:
#
# خوش‌طعم
#
# الهام بخش بصری
#
# ولی اگر رژیم فکری تیم فقط این باشد، سوءتغذیه می‌گیرند
#
# کنارش باید:
#
# مردان دیوانه → عمق
#
# مانیبال → داده
#
# معضل اجتماعی ← اخلاق
#
# Emily in Paris → فرهنگ امروز
#
# با این ترکیب، تیم هم ترند را می‌فهمد، هم فریبش را نمی‌خورد.

# %% [markdown]
# prompt_components
# Components of a Professional Prompt
#
# Role / Persona
# AI needs to understand who it is.
# Example: Copywriter, social media manager, brand strategist.
#
# Goal / Objective
# What is the output meant to achieve?
# Example: Increase engagement, generate leads, educate audience.
#
# Context / Background
# Brand identity, audience type, product details, platform.
#
# Constraints / Limitations
# Tone, style, length, forbidden words, brand rules.
#
# Output Format
# List, paragraph, caption, script, etc.

# %% [markdown]
# Components of a Professional Prompt
#
# Role / Persona
# AI needs to understand who it is.
# Example: Copywriter, social media manager, brand strategist.
#
# Goal / Objective
# What is the output meant to achieve?
# Example: Increase engagement, generate leads, educate audience.
#
# Context / Background
# Brand identity, audience type, product details, platform.
#
# Constraints / Limitations
# Tone, style, length, forbidden words, brand rules.
#
# Output Format
# List, paragraph, caption, script, etc.
#
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# dos_and_donts.md
# Dos
#
# Be explicit with audience and purpose
#
# Specify tone and style
#
# Provide platform or format
#
# Don’ts
#
# One-line vague instructions
#
# Assuming AI knows your brand
#
# Skipping constraints
#
# Example:
#
# Bad Prompt:

# %%
Write a marketing caption for our restaurant.

# %%
You are a social media copywriter for a fast-casual urban restaurant.
Audience: 20–30 year olds
Tone: friendly, witty, professional
Goal: increase Instagram engagement
Length: max 2 lines

# %% [markdown]
# prompt_iterations.md
# Iterative Prompting
#
# Often, the first prompt does not give perfect output.
# Iteration = key to professional prompting.
#
# Steps
#
# Draft initial prompt
#
# Evaluate output
#
# Refine prompt with additional context, examples, or constraints
#
# Repeat until output aligns with goal
#
# Tip:
# Use multi-step prompting for complex tasks:
#
# Step 1: Generate ideas
#
# Step 2: Refine ideas
#
# Step 3: Final output in desired format

# %% [markdown]
# debugging_prompts.md
# How to Debug a Prompt
#
# Common issues:
#
# Output too generic
#
# Tone inconsistent
#
# Length wrong
#
# Debugging techniques
#
# Add clarity to role and audience
#
# Specify tone and format more clearly
#
# Give examples of what is good/bad

# %% [markdown]
# exercises/ex01_create_structured_prompt.md
# Exercise 01 - All Exercises First Find These Also Create Your First Structured Prompt
#
# Task:
# Choose a product or campaign and create a structured prompt including:
#
# Role
#
# Audience
#
# Goal
#
# Tone
#
# Constraints
#
# Output Format
#
#
# تمرین 01 - همه تمرانت اول اینا هم پیدا کنین  اولین پیام ساختار یافته خود را ایجاد کنید
#
# وظیفه:
# یک محصول یا کمپین را انتخاب کنید و یک پیام ساختار یافته شامل موارد زیر ایجاد کنید:
#
# نقش
#
# مخاطب
#
# هدف
#
# لحن
#
# محدودیت‌ها
#
# فرمت خروجی

# %% [markdown]
# # **SESSION 2**

# %% [markdown]
# # Phase: Marketing-Core Prompting
#
# This notebook helps you practice creating **targeted content with brand tone and powerful CTA**.
#
# ---
#
# ## 1. Problem We Solve
# There is a lot of content, but **no brand impact**.
# Goal: Create content that is both **effective and brand-aligned**, and drives sales.
#
# ---
#
# ## 2. Copywriting Prompt
#
# ### Content Structure
# 1. **Headline**: Short, catchy, direct
# 2. **Body**: Explain the benefit or product, show audience need
# 3. **CTA (Call To Action)**: Direct and clear, prompts the audience to take action

# %%
# Enter your product or service
product_name = "Example: Sales-Boosting Prompts"

# Headline
headline = "Your marketing team produces content but it doesn't convert?"

# Body
body = f"With {product_name}, create content that not only gets noticed but also drives real sales."

# CTA
cta = "Get it now"

# Display content
print("Headline:", headline)
print("Body:", body)
print("CTA:", cta)
# Out:
# Headline: Your marketing team produces content but it doesn't convert?
# Body: With Example: Sales-Boosting Prompts, create content that not only gets noticed but also drives real sales.
# CTA: Get it now

# %% [markdown]
# Storytelling Prompt
# Content Structure
#
# Problem: Audience pain or need
#
# Empathy: Show brand understands their problem
#
# Solution: Introduce your product or service
