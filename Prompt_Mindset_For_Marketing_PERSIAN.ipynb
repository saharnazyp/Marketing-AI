# %% [markdown]
# <a href="https://colab.research.google.com/github/saharnazyp/Marketing-AI/blob/main/Prompt_Mindset_For_Marketing_PERSIAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## جلسه دوم

# %% [markdown]
#  بیل گیتس:محتوا پادشاه است
# Content is King

# %% [markdown]
# ## 🧱 ساختار استاندارد یک پرامپت حرفه‌ای (Framework)
# **🎯 1. نقش (Role)**
#
# بگو هوش مصنوعی در چه نقشی جواب بدهد:

# %%
تو یک معلم حرفه‌ای زبان انگلیسی هستی

# %% [markdown]
# **🎯2. هدف (Goal)**
#
# دقیقاً بگو چه می‌خواهی:

# %%
می‌خواهم گرامر زمان حال کامل را یاد بگیرم

# %% [markdown]
# **🎯 3. زمینه / کانتکست (Context)**
#
# شرایط، مخاطب، سطح:

# %%
سطحم متوسط است و برای مکالمه روزمره نیاز دارم

# %% [markdown]
# **🎯 4. قالب خروجی (Format)**
#
# خروجی را کنترل کن:

# %%
🎯 4. قالب خروجی (Format)

خروجی را کنترل کن:

# %%
در قالب جدول + مثال + تمرین

# %% [markdown]
# **🎯 5. محدودیت‌ها (Constraints)**
#
# حد و مرز:

# %%
ساده، بدون اصطلاحات دانشگاهی، با مثال واقعی

# %% [markdown]
# **✅ نمونه پرامپت کامل:**

# %%
تو یک معلم حرفه‌ای زبان انگلیسی هستی.
می‌خواهم زمان حال کامل را یاد بگیرم.
سطحم متوسط است و هدفم مکالمه روزمره است.
آموزش را در قالب جدول، مثال و تمرین بده.
ساده توضیح بده و از مثال‌های واقعی استفاده کن.

# %% [markdown]
# 🧩 تکنیک‌های حرفه‌ای پرامپت‌نویسی
# 🔹 1. Chain of Thought (تفکر مرحله‌ای)

# %%
مرحله‌به‌مرحله فکر کن و سپس جواب نهایی را بده

# %% [markdown]
# 📌 خروجی دقیق‌تر و منطقی‌تر

# %% [markdown]
# 🔹 2. Few-shot Prompting (مثال دادن)

# %%
مثال:
سؤال: ...
پاسخ: ...
حالا تو مشابهش را انجام بده

# %% [markdown]
# 🔹 3. Ask to Critique (نقد کن)

# %%
اول پاسخ بده، بعد خودت پاسخت را نقد کن

# %% [markdown]
# 🔹 4. Persona Prompting

# %%
مثل یک مدیر محصول گوگل توضیح بده

# %% [markdown]
# 🔹 5. Iterative Prompting (اصلاح مرحله‌ای)
#
# اول:
#
# یک متن بنویس
# بعد:
# رسمی‌ترش کن
# بعد:
# کوتاه‌تر
# بعد:
# با مثال
#
#
#
# ### **🎨 پرامپت‌نویسی برای تصویر (Image Prompt)**
# فرمول طلایی:

# %%
موضوع + جزئیات + سبک هنری + نور + زاویه + کیفیت

# %% [markdown]
# مثال

# %%
A cinematic portrait of a Persian woman,
wearing traditional clothes,
digital painting, ultra realistic,
soft lighting, 4k, shallow depth of field

# %% [markdown]
# 📌 نکات مهم:
#
# انگلیسی بهتر جواب می‌دهد
#
# جزئیات خیلی مهم‌اند
#
# سبک (realistic, anime, oil painting…)

# %% [markdown]
# **🎥 پرامپت‌نویسی برای ویدیو (AI Video)**
# اجزای مهم:
#
# صحنه
#
# حرکت
#
# دوربین
#
# حس و فضا
#
# مدت
#
# مثال:

# %%
A slow-motion cinematic video of a man walking in rain,
dark mood, dramatic lighting,
camera tracking shot, 5 seconds

# %% [markdown]
# **✍️ پرامپت‌نویسی برای متن (نویسندگی، کدنویسی، آموزش)**
# مثال تولید محتوا:

# %%
تو یک کپی‌رایتر حرفه‌ای هستی.
یک کپشن اینستاگرام برای فروش دوره پرامپت‌نویسی بنویس.
لحن صمیمی، ترغیب‌کننده و کوتاه باشد.

# %%
تو یک کپی‌رایتر حرفه‌ای هستی.
یک کپشن اینستاگرام برای فروش دوره پرامپت‌نویسی بنویس.
لحن صمیمی، ترغیب‌کننده و کوتاه باشد.

# %% [markdown]
# **🛠️ اشتباهات رایج مبتدی‌ها**
#
# ❌ خیلی کلی نوشتن
# ❌ مشخص نکردن نقش
# ❌ نخواستن قالب خروجی
# ❌ انتظار معجزه با یک خط
# ❌ اصلاح نکردن پرامپت

# %% [markdown]
# **🚀 تمرین طلایی (حتماً انجام بده)**
#
# 1️⃣ یک پرامپت ضعیف بنویس
# 2️⃣ با این سوال‌ها اصلاحش کن:
#
# دقیقاً چی می‌خوام؟
#
# برای کی؟
#
# خروجی چه شکلی؟
#
# چه محدودیتی دارد؟

# %% [markdown]
# ## فاز: پرامپت‌نویسی مارکتینگ‌محور (Marketing Core)
#
# این نوت‌بوک به شما کمک می‌کند تا مهارت تولید محتوا **هدفمند، با لحن برند و با CTA قدرتمند** را تمرین کنید.
#
# ---
#
# ## ۱. مسئله‌ای که حل می‌کنیم
# تولید محتوا زیاد است، ولی **برند ندارد**.
# هدف: محتوای اثرگذار بسازیم که هم ارزش برند را منتقل کند و هم فروش ایجاد کند.
#
# ---
#
# ## ۲. پرامپت برای کپی فروش (Copywriting)
#
# ### ساختار محتوا
# 1. **تیتر (Headline)**: کوتاه، جذاب، مستقیم
# 2. **بدنه (Body)**: توضیح مزیت یا محصول، نشان دادن نیاز مخاطب
# 3. **CTA (Call To Action)**: مستقیم و واضح، مخاطب را به اقدام دعوت می‌کند
#
# ### تمرین

# %%
# محصول یا سرویس خود را وارد کنید
product_name = "مثال: پرامپت‌های فروش‌ساز"

# تیتر
headline = "تیم مارکتینگت محتوا تولید می‌کنه ولی فروش نمی‌سازه؟"

# بدنه
body = f"با {product_name}، محتواهایی بساز که نه فقط دیده بشن، بلکه فروش واقعی ایجاد کنند."

# CTA
cta = "همین الان دریافت کن"

# نمایش محتوا
print("تیتر:", headline)
print("بدنه:", body)
print("CTA:", cta)
# Out:
# تیتر: تیم مارکتینگت محتوا تولید می‌کنه ولی فروش نمی‌سازه؟
# بدنه: با مثال: پرامپت‌های فروش‌ساز، محتواهایی بساز که نه فقط دیده بشن، بلکه فروش واقعی ایجاد کنند.
# CTA: همین الان دریافت کن

# %% [markdown]
# **پرامپت برای Storytelling**
#
# ساختار محتوا
#
# مشکل (Problem): درد یا نیاز مخاطب
#
# همدلی (Empathy): نشان دادن درک برند از مشکل
#
# راه‌حل (Solution): معرفی محصول یا سرویس

# %%
problem = "تلاش می‌کنید محتوا بسازید اما نتیجه نمی‌گیرید؟"
empathy = "ما می‌دانیم چقدر ناامیدکننده است وقتی تلاش می‌کنید اما فروش نمی‌بینید."
solution = f"با {product_name}، محتوای شما به فروش تبدیل می‌شود."

print("مشکل:", problem)
print("همدلی:", empathy)
print("راه‌حل:", solution)
# Out:
# مشکل: تلاش می‌کنید محتوا بسازید اما نتیجه نمی‌گیرید؟
# همدلی: ما می‌دانیم چقدر ناامیدکننده است وقتی تلاش می‌کنید اما فروش نمی‌بینید.
# راه‌حل: با مثال: پرامپت‌های فروش‌ساز، محتوای شما به فروش تبدیل می‌شود.

# %% [markdown]
# **پرامپت برای ارزش پیشنهادی (Value Proposition)**

# %%
value_proposition = "راهی سریع برای افزایش فروش بدون نیاز به صرف زمان زیاد."
print("ارزش پیشنهادی:", value_proposition)
# Out:
# ارزش پیشنهادی: راهی سریع برای افزایش فروش بدون نیاز به صرف زمان زیاد.

# %% [markdown]
# **کنترل لحن (Tone of Voice)**
#
# لحن‌های قابل انتخاب:
#
# لوکس
#
# دوستانه
#
# جوان
#
# رسمی سازمانی

# %%
tone = "دوستانه"  # تغییر دهید: لوکس / دوستانه / جوان / رسمی سازمانی
print(f"لحن انتخاب شده: {tone}")
# Out:
# لحن انتخاب شده: دوستانه

# %% [markdown]
# **تمرین عملی**
#
# برای یک محصول مشخص، سه لحن، سه مخاطب، سه هدف بسازید:

# %%
# محصولات
product = "پرامپت‌های فروش‌ساز"

# لحن‌ها
tones = ["لوکس", "دوستانه", "جوان"]

# مخاطب‌ها
audiences = ["جدید", "آگاه", "حرفه‌ای"]

# اهداف
goals = ["آگاهی", "فروش", "وفاداری"]

for t in tones:
    for a in audiences:
        for g in goals:
            print(f"\n---\nلحن: {t} | مخاطب: {a} | هدف: {g}")
            print(f"تیتر: {product} مناسب برای {a} با هدف {g}")
            print(f"CTA: همین الان امتحان کن!")
# Out:
# ---
# لحن: لوکس | مخاطب: جدید | هدف: آگاهی
# تیتر: پرامپت‌های فروش‌ساز مناسب برای جدید با هدف آگاهی
# CTA: همین الان امتحان کن!
#
# ---
# لحن: لوکس | مخاطب: جدید | هدف: فروش
# تیتر: پرامپت‌های فروش‌ساز مناسب برای جدید با هدف فروش
# CTA: همین الان امتحان کن!
#
# ---
# لحن: لوکس | مخاطب: جدید | هدف: وفاداری
# تیتر: پرامپت‌های فروش‌ساز مناسب برای جدید با هدف وفاداری
# CTA: همین الان امتحان کن!
#
# ---
# لحن: لوکس | مخاطب: آگاه | هدف: آگاهی
# تیتر: پرامپت‌های فروش‌ساز مناسب برای آگاه با هدف آگاهی
# CTA: همین الان امتحان کن!
#
# ---
# لحن: لوکس | مخاطب: آگاه | هدف: فروش
# تیتر: پرامپت‌های فروش‌ساز مناسب برای آگاه با هدف فروش
# CTA: همین الان امتحان کن!
#
# ---
# لحن: لوکس | مخاطب: آگاه | هدف: وفاداری
# تیتر: پرامپت‌های فروش‌ساز مناسب برای آگاه با هدف وفاداری
# CTA: همین الان امتحان کن!
#
# ---
# لحن: لوکس | مخاطب: حرفه‌ای | هدف: آگاهی
# تیتر: پرامپت‌های فروش‌ساز مناسب برای حرفه‌ای با هدف آگاهی
# CTA: همین الان امتحان کن!
#
# ---
# لحن: لوکس | مخاطب: حرفه‌ای | هدف: فروش
# ...

# %% [markdown]
# **خروجی فاز**
#
# بعد از اجرای این نوت‌بوک، تیم می‌تواند:
#
# کپی هدفمند بسازد
#
# لحن برند را حفظ کند
#
# CTA اثرگذار طراحی کند
#
# Storytelling و ارزش پیشنهادی را در متن اعمال کند

# %% [markdown]
# ### تمرین
#
# #### تمرین عملی Marketing Core بدون کدنویسی
#
# این تمرین به شما کمک می‌کند
# **برای ۸ برند محتوا هدفمند بسازید**
# و تمرین Storytelling، CTA، ارزش پیشنهادی و لحن برند را انجام دهید.
#
# **🧠 تمرین صفر (خیلی مهم – فقط یک بار انجام بده)**
#
# قبل از هر پرامپت، این ۵ سؤال رو جواب بده (حتی تو ذهنت):
#
# مخاطب کیه؟
#
# حس برند چیه؟ (لوکس؟ فان؟ سنتی؟ جوان‌پسند؟)
#
# هدف پست چیه؟ (فروش، وایرال، اعتماد، تعامل)
#
# فرمت چیه؟ (پست، ریلز، استوری)
#
# CTA چیه؟
# ---
#
# ## ۱. فهرست برندها
# روی کاغذ یا Google Sheet فهرست زیر را آماده کنید:
# **Chicken Factory, Burger Factory, Libro, Romatay, Lafo, Delish, SPO Express, SPO Royal**
#
# ---
#
# ## ۲. ستون‌بندی برای Marketing Core
#
# | برند | لحن | مخاطب | هدف | تیتر | بدنه | CTA | ارزش پیشنهادی |
# |------|------|--------|-----|------|------|-----|----------------|
# | Chicken Factory | دوستانه | جدید | فروش | … | … | … | … |
#
# > نکته: می‌توانید ستون‌ها را در Google Sheet یا Excel بسازید و پر کنید.
#
# ---
#
# ## ۳. تولید محتوا
#
# برای هر برند و هر ترکیب لحن/مخاطب/هدف:
#
# - **تیتر:** کوتاه، جذاب و مستقیم
# - **بدنه:** مشکل مخاطب + راه‌حل محصول یا سرویس
# - **CTA:** عملی و روشن (مثلاً «همین الان امتحان کن»)
# - **ارزش پیشنهادی:**
#  چرا برند/محصول ارزشمند است
#
# ---
#
# ## ۴. تمرین Storytelling
#
# - مشکل → همدلی → راه‌حل
# - این بخش را می‌توانید در ستون‌های جدا یا کنار بدنه اضافه کنید
#
# ---
#
# ## ۵. پالایش محتوا
#
# - متن‌ها را چند بار بخوانید و ویرایش کنید
# - مطمئن شوید لحن برند در همه محتواها **یکسان و ثابت** باشد
#
# ---
#
# **هدف تمرین:**
#  بعد از این تمرین، شما می‌توانید **برای همه برندها محتواهای حرفه‌ای و اثرگذار بسازید** که هم هویت برند را حفظ می‌کند و هم مخاطب را به اقدام واقعی هدایت می‌کند.
#
#  لینک کمکی:
#  https://docs.google.com/document/d/1TGXZCtj0-KNhiQwCYrvLMqhK-pfofqc5yBtK-_QDH1A/edit?usp=sharing

# %% [markdown]
# # جلسه سوم

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **پرامپت تصویر و ویدیو (Visual Prompting)**
#
# چرا این فاز مهم است؟
#
# در دنیای امروز، تصویر قبل از متن دیده می‌شود.
#
# مغز انسان تصویر را چندین برابر سریع‌تر از متن پردازش می‌کند.
#
# بیشتر برندها تصویر دارند، اما هویت ندارند.
#
# خروجی AI اگر هدایت نشود، زیباست ولی بی‌برند و بی‌هدف است.
#
# این فاز به تیم یاد می‌دهد:
#
# چطور AI تصویرساز را از «نقاش ناشی» به «طراح برندمحور» تبدیل کند.
#
#
# مسئله‌ای که این فاز حل می‌کند
# مشکل رایج:
#
# تصویر هست، ولی اگر لوگو را برداری، نمی‌فهمی مال چه برندی است
#
# تصاویر قشنگ‌اند، اما پیام ندارند
#
# خروجی‌ها شبیه هم‌اند (همان سبک‌های تکراری AI)
#
# ریشه مشکل:
#
# AI تصویرساز سلیقه ندارد
# AI فقط دستور اجرا می‌کند، نه تصمیم برند.
#
# پس:
#
# اگر پرامپت ضعیف باشد → خروجی بی‌هویت است
# اگر پرامپت دقیق باشد → خروجی برندمحور است

# %% [markdown]
# ## 🎨🎥 Visual Prompting
#
# **Visual Prompting یعنی:**
# تبدیل ایده‌ی ذهنی به دستور دقیق برای تولید تصویر یا ویدیو با AI
#
# هر چی دقیق‌تر ببینی → دقیق‌تر بنویسی → خروجی حرفه‌ای‌تر بگیری.
#
# نوشتن دستور دقیق برای اینکه AI:
#
# * چه چیزی را بکشد
# * با چه حس و سبکی
# * در چه نوری
# * با چه عناصر برند
#
# در واقع:
#
# > پرامپت تصویری = بریف طراحی حرفه‌ای
#
#
# 🧠 طرز فکر (Mindset)
#
# قبل از نوشتن پرامپت، باید مثل این آدم‌ها فکر کنی:
#
# عکاس 📸
#
# کارگردان 🎬
#
# نورپرداز 💡
#
# گرافیست 🎨
# ---
#
# ## اجزای اصلی پرامپت تصویری (خیلی مهم)
#
# هر پرامپت تصویری حرفه‌ای باید این ۵ بخش را داشته باشد:
#
# ---
#
# ### ۱. Subject (سوژه)
#
# **سوژه یعنی: دقیقاً چه چیزی در تصویر است؟**
#
# ❌ اشتباه:
#
# > a restaurant poster
#
# ✅ درست:
#
# > a modern fast-food restaurant counter with a smiling staff member holding a branded burger box
#
# سوژه باید:
#
# * مشخص
# * قابل تصور
# * بدون ابهام باشد
#
# ---
#
# ### ۲. Style (سبک)
#
# **سبک یعنی تصویر شبیه چه چیزی باشد؟**
#
# مثال‌ها:
#
# * minimal
# * cinematic
# * luxury
# * street photography
# * illustration
# * 3D render
#
# سبک تعیین می‌کند:
#
# * تصویر رسمی است یا جوان؟
# * لوکس است یا دوستانه؟
# * هنری است یا تجاری؟
#
# ---
#
# ### ۳. Mood (حس)
#
# **Mood یعنی تصویر چه احساسی منتقل کند؟**
#
# مثال‌ها:
#
# * energetic
# * warm
# * premium
# * fun
# * calm
# * bold
#
# این بخش مستقیماً به **احساس برند** وصل است.
#
# ---
#
# ### ۴. Lighting (نور)
#
# نور یعنی:
#
# * تصویر روشن است یا تاریک؟
# * دراماتیک است یا ساده؟
# * طبیعی است یا استودیویی؟
#
# مثال:
#
# * soft natural light
# * cinematic dramatic lighting
# * bright daylight
# * warm ambient light
#
# نور اشتباه = حس اشتباه
# نور درست = برند درست
#
# ---
#
# ### ۵. Brand Elements (عناصر برند)
#
# مهم‌ترین بخش.
#
# شامل:
#
# * رنگ‌های برند
# * فضا (مدرن، سنتی، صنعتی، لوکس…)
# * vibe برند
#
# مثال:
#
# > using brand colors red and black, modern urban atmosphere, clean composition
#
# اینجاست که تصویر «مال شما» می‌شود.
#
# ---
#
# ## چطور با پرامپت تصویری خروجی بسازند؟
#
# ### ۱. پوستر تبلیغاتی
#
# هدف:
#
# * انتقال پیام
# * جلب توجه
# * هویت برند
#
# پرامپت باید:
#
# * سوژه واضح
# * حس قوی
# * فضای تبلیغاتی داشته باشد
#
# ---
#
# ### ۲. بنر تبلیغاتی
#
# هدف:
#
# * سریع دیده شود
# * پیام ساده
# * قابل استفاده در سایت یا تبلیغات
#
# پرامپت:
#
# * ساده‌تر
# * تمرکز روی یک عنصر
# * فضای خالی (negative space)
#
# ---
#
# ### ۳. کاور شبکه اجتماعی
#
# هدف:
#
# * توقف اسکرول
# * انتقال حس برند
# * هماهنگی با بقیه پست‌ها
#
# پرامپت:
#
# * قوی در Mood
# * سازگار با لحن برند
# * قابل تکرار در سری محتوا
#
# ---
#
# ## تمرین عملی (بخش بسیار مهم)
#
# ### تمرین:
#
# **یک برند → ۳ کانسپت تصویری کاملاً متفاوت**
#
# مثلاً برای یک برند غذایی:
#
# 1. کانسپت احساسی (Warm & Friendly)
# 2. کانسپت جوان و پرانرژی (Bold & Modern)
# 3. کانسپت لوکس (Premium & Clean)
#
# برای هر کانسپت:
#
# * سوژه فرق دارد
# * حس فرق دارد
# * نور فرق دارد
# * اما **برند ثابت می‌ماند**
#
# این تمرین مغز تیم را از «تولید تصویر» به «طراحی کانسپت» می‌برد.
#
# ---
#
# ## خروجی این فاز چیست؟
#
# بعد از این فاز، تیم می‌فهمد که:
#
# 1. AI تصویرساز **طراح نیست**
# 2. AI تصویرساز **بی‌سلیقه است**
# 3. AI فقط اجرا می‌کند
#
# و نتیجه‌ی طلایی:
#
# > **AI تصویرساز = طراح بی‌سلیقه‌ای که باید هدایت شود**
#
# کسی که پرامپت بلد است:
#
# * کنترل دارد
# * برند می‌سازد
# * تصویر تکراری تولید نمی‌کند
#
# ---
#
# ## جمع‌بندی نهایی
#
# این فاز به تیم یاد می‌دهد:
#
# * تصویر فقط زیبایی نیست، **هویت است**
# * پرامپت تصویری، بریف طراحی است
# * برند بدون کنترل بصری، دیده نمی‌شود
# * AI بدون هدایت، برند را نابود می‌کند

# %% [markdown]
# 🧱 فرمول طلایی Visual Prompting (حفظش کن)
# فرمول پایه:

# %%
Subject + Action + Details + Style + Lighting + Camera + Quality

# %% [markdown]
# 🧩 تشریح کامل اجزا (خیلی مهم)
# 1️⃣ Subject (سوژه)
#
# چی یا کی تو تصویر/ویدیو هست؟

# %%
A juicy burger
A Persian traditional dish
A luxury cafe interior

# %% [markdown]
# 🧩 تشریح کامل اجزا (خیلی مهم)
# 1️⃣ Subject (سوژه)
#
# چی یا کی تو تصویر/ویدیو هست؟

# %%
🧩 تشریح کامل اجزا (خیلی مهم)
1️⃣ Subject (سوژه)

چی یا کی تو تصویر/ویدیو هست؟

# %% [markdown]
# 2️⃣ Action (حرکت – مخصوص ویدیو)
#
# چی داره اتفاق می‌افته؟

# %%
2️⃣ Action (حرکت – مخصوص ویدیو)

چی داره اتفاق می‌افته؟

# %% [markdown]
# 3️⃣ Details (جزئیات)
#
# مهم‌ترین بخش 👇

# %%
crispy texture, golden color, fresh ingredients

# %% [markdown]
# 4️⃣ Style (سبک)
#
# حس و حال تصویر:

# %%
food photography
cinematic
minimalist
luxury
traditional Persian style

# %% [markdown]
# 5️⃣ Lighting (نور)
#
# فرق عکس معمولی و حرفه‌ای:

# %%
soft natural light
dramatic lighting
warm light
low-key lighting

# %% [markdown]
# 6️⃣ Camera (دوربین)
#
# دید حرفه‌ای:

# %%
close-up
top view
macro shot
shallow depth of field
tracking shot (ویدیو)

# %% [markdown]
# 7️⃣ Quality (کیفیت)
#
# خروجی نهایی:

# %%
ultra realistic, 4k, high detail

# %% [markdown]
# 📸 مثال کامل – تصویر

# %%
Ultra realistic close-up of a juicy cheeseburger,
melting cheese, crispy beef patty,
food photography, dramatic lighting,
shallow depth of field, 4k

# %% [markdown]
# 🎬 مثال کامل – ویدیو

# %%
Cinematic slow-motion video of coffee pouring into a cup,
warm lighting, shallow depth of field,
luxury cafe atmosphere, 5 seconds

# %% [markdown]
# لینک کمکی:https://docs.google.com/document/d/1TGXZCtj0-KNhiQwCYrvLMqhK-pfofqc5yBtK-_QDH1A/edit?tab=t.0

# %% [markdown]
# # جلسه چهارم

# %% [markdown]
# ##جلسه پنجم

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **کپشن نویسی**
# سوالی بنویسید که ذهن مخاطب را درگیر کرده است:
# جمله‌ای بنویسید که کنجکاوی ایجاد کند:
# حقه‌ای بزنید که مخاطب را ترغیب به خواندن کند:
#
#
#
# تفاوت کپشن بر اساس پلتفرم
# اینستاگرام
#
# ویژگی‌ها: بصری، احساسی، کوتاه
#
# نوع محتوا: کپشن کوتاه، ریلز جذاب، استوری تعاملی
#
# هدف: توقف اسکرول، ایجاد تعامل سریع، انتقال احساس برند
#
# لینکدین
#
# ویژگی‌ها: حرفه‌ای، تحلیلی، ارزش‌آفرین
#
# نوع محتوا: کپشن حرفه‌ای، مقاله کوتاه، ریلز تحلیلی
#
# هدف: جلب اعتماد حرفه‌ای، ایجاد اعتبار برند، انتقال تخصص
#
# واتس‌اپ بیزینس
#
# ویژگی‌ها: مستقیم، انسانی، شخصی‌سازی‌شده
#
# نوع محتوا: پیام مستقیم، استیکر یا پیام تعاملی، پاسخ خودکار هوشمند
#
# هدف: ایجاد رابطه شخصی با مخاطب، هدایت به اقدام فوری

# %% [markdown]
# # فاز عملی: کپشن مخصوص شبکه‌های اجتماعی
#
# بعد از چک تمرین Marketing Core،
# حالا وارد عملی‌ترین بخش می‌شویم:
#
#
#  **ساخت محتوای شبکه‌های اجتماعی با پرامپت‌های هدفمند**.
# بعد از فاز Marketing Core، تیم شما حالا می‌تواند متن‌های هدفمند و با لحن برند بسازد.
# اما تولید محتوا برای شبکه‌های اجتماعی نیاز به سفارشی‌سازی برای هر پلتفرم دارد.
#
# شبکه‌های اجتماعی هر کدام رفتار کاربر متفاوت دارند:
#
# اینستاگرام: بصری، سریع، احساسی، کوتاه
#
# لینکدین: حرفه‌ای، تحلیلی، آموزنده
#
# واتس‌اپ بیزینس: مستقیم، انسانی، شخصی
#
# هدف این فاز این است که تیم کمپین‌های واقعی و اثرگذار بسازد، نه فقط پست تکی.
# ---
#
# ## ۱. مسئله‌ای که حل می‌کنیم
# شاید کپی شما خوب باشد، اما **با پلتفرم شبکه اجتماعی هم‌خوانی ندارد**.
# یعنی محتوا:
# - اسکرول کاربران را متوقف نمی‌کند
# - تعامل ایجاد نمی‌کند
# - لحن برند یا فرمت مناسب پلتفرم را ندارد
#
# هدف این فاز: تولید محتوا برای شبکه‌های اجتماعی که
# **هم جذاب، هم تعامل‌ساز و هم برندمحور باشد**.
#
# ---
#
# ## ۲. آموزش پرامپت بر اساس پلتفرم
#
# - **اینستاگرام** → احساسی، کوتاه، جذاب، دیداری
# - **لینکدین** → تحلیلی، حرفه‌ای، دقیق، ارزش‌آفرین
# - **واتس‌اپ بیزینس** → مستقیم، انسانی، شخصی‌سازی‌شده
#
# ### انواع محتوا
# - **کپشن** → متن کوتاه و اثرگذار
# - **ریلز** → Hook (جلب توجه) + Script (متن اصلی و داستان)
# - **استوری تعاملی** → نظرسنجی، سوال، بازی کوچک
# - **کامنت‌سازی هوشمند** → ایجاد تعامل و پاسخ‌دهی خودکار
#
#
# | پلتفرم         | لحن و سبک                   | نوع محتوا                                    |
# | -------------- | --------------------------- | -------------------------------------------- |
# | اینستاگرام     | احساسی، کوتاه، جذاب         | کپشن، ریلز، استوری تعاملی                    |
# | لینکدین        | تحلیلی، حرفه‌ای، ارزش‌آفرین | کپشن حرفه‌ای، مقاله کوتاه، ریلز تحلیلی       |
# | واتس‌اپ بیزینس | مستقیم، انسانی، شخصی        | پیام مستقیم، استیکر/پیام تعاملی، پاسخ هوشمند |
#
#
# ---
#
# ## ۳. نکته طلایی
# یک پرامپت شبکه اجتماعی موفق باید:
# 1. اسکرول کاربران را متوقف کند
# 2. تعامل بسازد (لایک، کامنت، اشتراک‌گذاری)
# 3. هویت و لحن برند را حفظ کند
#
# > این بخش عملی‌ترین قسمت دوره است؛ اینجاست که کپی‌های شما تبدیل به **کمپین واقعی و پول‌ساز** می‌شوند.
#
# ---
#
# ## ۴. تمرین عملی
# **هدف:** طراحی یک **کمپین ۷ روزه فقط با پرامپت**
#
# مراحل تمرین:
# 1. انتخاب یک برند از لیست ۸ برند
# 2. مشخص کردن پلتفرم هدف (اینستاگرام، لینکدین، واتس‌اپ)
# 3. طراحی محتوای روزانه شامل:
#    - کپشن
#    - ریلز (Hook + Script)
#    - استوری تعاملی
#    - کامنت‌سازی هوشمند
# 4. پالایش و اطمینان از ثبات لحن برند و ایجاد تعامل
#
# > می‌توانید این تمرین را در **Google Sheet یا Excel** انجام دهید و هر روز یک ردیف به یک محتوا اختصاص دهید.
#
# ---
#
# ## ۵. خروجی فاز
# - یک کمپین کامل و ۷ روزه بچیند
# - محتوای شبکه اجتماعی بسازد که
# **نه تنها پست تکی بلکه جریان برند و تعامل واقعی ایجاد می‌کند**
# - لحن و هویت برند را در تمام پست‌ها حفظ کند
# - تعامل و بازخورد کاربران را افزایش دهد

# %% [markdown]
# [copy.ai](https://www.copy.ai/)
# [ahrefs](https://ahrefs.com/)
# [conductor](https://www.conductor.com/alternative-to/ai-content-tools/?utm_medium=cpc&utm_source=google&utm_campaign=GO_SEM_Text_NonBrand_SmallAICompetitors_US&utm_content=Writesonic&utm_term=writesonic&gad_source=1&gad_campaignid=23317693439&gbraid=0AAAAAD_SDT2da0aB_hEk12813DURkGLiZ&gclid=CjwKCAiA09jKBhB9EiwAgB8l-Hb1HVOBDHUJTvYeSm97jmEV2epwVB_RrXYjKryQTxAQ06gcrKbtGRoCmH0QAvD_BwE)
#
# [hoppycopy](https://www.hoppycopy.co)
# [jasper](https://www.jasper.ai/)
# [writer](https://writer.com/?nav=2&footer=1&utm_matchtype=b&utm_device=c&utm_ad=764346132191&utm_source=google&utm_medium=cpc&utm_campaign=&utm_term=agentic%20ai%20for%20enterprise&utm_content=&hsa_acc=8779610535&hsa_cam=22801776449&hsa_grp=182107998946&hsa_ad=764346132191&hsa_src=g&hsa_tgt=kwd-2399732670185&hsa_kw=agentic%20ai%20for%20enterprise&hsa_mt=b&hsa_net=adwords&hsa_ver=3&gad_source=1&gad_campaignid=22801776449&gbraid=0AAAAAoz5SaaXwTivutBiLAlDPME6JNFKB&gclid=CjwKCAiA09jKBhB9EiwAgB8l-C4B0CQrjHsiqALNCO9RtIkdmUSYE-Mh7NlNlSb0lRYcmnNOlFWiKRoC6TMQAvD_BwE)
# [rytr](https://rytr.me/)

# %% [markdown]
# # اسلاید های ارائه

# %% [markdown]
# https://docs.google.com/presentation/d/1aKF8aPQ4tHtTF-93JaThKR9fv9Y_A5YfG7AP1exXUCc/edit

# %% [markdown]
# # OPEN AI **رایگان**

# %% [markdown]
# مرحله اول وارد این سایت میشین
#
# https://em.bjedu.tech/en/
#
#
# ![1.png](data:image/png;base64,...)

# %% [markdown]
# حتما رو گزینه سوم بزنین و نام ایمیل انتخاب کنید
#
#
# ![2.png](data:image/png;base64,...)

# %% [markdown]
# لینک را کپی کنین این لینک ورود به ایمل آدرس شماس
#
#
# ![3.png](data:image/png;base64,...)

# %% [markdown]
# وارد سایت
# https://chatgpt.com/
# شوید و لاگین بزنین
# ![4.png](data:image/png;base64,...)

# %% [markdown]
# یک کد به ایمیل شما ارسال شده روی آن کلیک کنین
#
# ![5.png](data:image/png;base64,...)

# %% [markdown]
# نام و نام خانوادگی و تاریخ تولدتان را درج نمایید
# ![6.png](data:image/png;base64,...)

# %% [markdown]
# تبریک میگم شما یک اکانت پولی و پرو
# CHAT GBT دارید
#
#
# ![7.png](data:image/png;base64,...)

# %% [markdown]
# # ابزار ها ی پرامپ نویسی

# %% [markdown]
# [Official ChatGPT website](https://chatgpt.com/)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [link text](https://gemini.google.com/)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [GROK](https://grok.com/)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [CLAUDE](https://claude.ai/)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [deepseek](https://www.deepseek.com/)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [Perpexity](https://www.perplexity.ai/)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#  [Copilot](https://copilot.microsoft.com/)
#  ![image.png](data:image/png;base64,...)

# %% [markdown]
# [Poe](https://poe.com/)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [mistral](https://mistral.ai/)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [meta.ai](https://www.meta.ai/)
# ![image.png](data:image/png;base64,...)
